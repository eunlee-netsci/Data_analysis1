# %% [markdown]
# # 필요한 파일과 모듈들을 임포트하여 다음 문제들을 수행하라

# %%
# import

# %% [markdown]
# # 1. bigmac.csv 데이터를 갖고 와서 국가별 연도별 빅맥 가격의 변화를 분석해보자.

# %% [markdown]
# ## 문제 1-1: 연도를 index, 국가를 열로 하는 데이터 구조로 변화시켜, 연도별 가격 '평균' 의 변화 추이를 살펴보라
# 그 중 Switzerland, Brazil, Korea 의 국가별 변화 추이를 선 그래프로 시각화하라. (마커 및 범례 적용)

# %%
#

# %% [markdown]
# ## 문제 1-2: stack()을 활용해 열을 '연도-국가-가격' 구조를 갖는 long 형식으로 바꾸고 일부만 출력하라

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#

# %% [markdown]
# # 문제 2: 도시-성별-항목 기준 소비 분석

# %% [markdown]
# ### foods.csv 데이터를 활용하도록 하자.

# %%
# 사용 데이터: foods.csv

# %% [markdown]
# ## 문제 2-1: (도시, 성별) 의 멀티인덱스와 'Item' 열을 갖도록 하고, 해당 항목별로 소비금액 평균을 구하여 표로 만들어보라

# %%
#

# %% [markdown]
# ## 문제 2-2: 위의 pivot 테이블을 stack()하여 3단계 인덱스로 만들고, 다시 음의 인덱스를 사용하여 원래 구조를 복원해보라

# %%
# 변환 전 구조 확인

# %%
# stack: 열(Item)을 인덱스로 이동하여 MultiIndex 형성

# %%
# 다시 unstack: 마지막 인덱스 수준(Item)을 다시 컬럼으로 복원

# %% [markdown]
# ## 문제 2-3: melt()를 사용하여 원본 데이터에서 long 형식으로 아이템별 소비금액 데이터를 구성하고, 도시별 평균 사용 금액을 막대 그래프로 시각화하라.

# %% [markdown]
# 이 때, identifier 로는 City, Gender 가 쓰이고, 값으로는 Spend, 변수 이름은 Type, 값의 이름은 Value 로 지정하라.

# %%
#

# %% [markdown]
# ## 문제 2-4: `First Name` 컬럼의 이름 길이를 계산하여 새로운 컬럼 `NameLength`에 저장하라. 이를 바탕으로 이름 길이에 따른 평균 소비액(`Spend`)을 산점도로 시각화하라.

# %%
#

# %% [markdown]
# ## 문제 2-5: 소비자가 `New York`에 거주하고 `Sushi`를 구입한 경우를 찾아내는 사용자 정의 함수 label_target(row) 를 작성하고, 해당 조건을 만족하면 `'Target'`, 아니면 `'Other'`로 분류한 `Tag` 컬럼을 추가하라. 이후 `Tag`별 평균 소비액을 비교하라 (apply 적용)

# %%
#

# %% [markdown]
# # 3. 분기별 판매 실적 구조를 분석해보자.

# %%
# 사용 데이터: quarters.csv

# %%
quarters.head()

# %% [markdown]
# ## 문제 3-1: melt()를 사용해 wide 포맷을 long 포맷으로 변형하라

# %%
#

# %% [markdown]
# ## 문제 3-2: 위 데이터를 pivot을 이용해 다시 wide 형식으로 복구하라

# %%
#

# %% [markdown]
# ## 문제 3-3: 판매원별로 melt() 후 분기별 평균 판매를 막대그래프로 나타내라 (groupby 혹은 pivot, unstack, stack 사용가능)

# %%
#

# %% [markdown]
# ## 문제 3-3: 위의 데이터프레임을 전치하여, 분기별 각 세일즈맨의 평균 판매량을 막대그래프로 그려보라.

# %%
#
