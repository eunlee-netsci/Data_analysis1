# %% [markdown]
# # W1. Series 를 이해하고 다룰 수 있게 된다.

# %% [markdown]
# * 항상 모듈은 맨 위에서 모두 모아서 한번에 로딩함.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Create a Series Object from a List
# - A pandas **Series** is a one-dimensional labelled array.
# - A Series combines the best features of a list and a dictionary.
# - A Series maintains a single collection of ordered values (i.e. a single column of data).
# - We can assign each value an identifier, which does not have to *be* unique.

# %% [markdown]
# * pandas 의 시리즈는 하나의 열로 이루어진 데이터라 생각할 수 있음.
# * 기존 파이썬의 딕셔너리와 리스트의 결합으로 생각할 수 있음.
# * 주어진 자료의 순서를 유지하며, 인덱스보다 알기 쉬운 identifier 를 주려고 함 (즉, 인덱스 이름 열 이름 자체)

# %%
ice_cream = ["Chocolate", "Vanilla", "Strawberry", "Rum Raisin"] # 파이썬 리스트
pd.Series(ice_cream) # S 가 대문자임. 주의할 것. 판다스 라이브러르에 들어있는 Series 클래스임.

# %% [markdown]
# #### Q. 여기서 알 수 있는 것은?

# %%
# 2개 이상 적어보자.

# %% [markdown]
# * dtype 은 시리즈에 들어있는 데이터의 타입: Object -> string 을 포함한 데이터타입을 말함.
# * list, dict 도 object 임.

# %% [markdown]
# ### 1-1) 리스트를 시리즈로

# %%
lottery_numbers = [4, 8, 15, 16, 23, 42]

# %% [markdown]
# * XXX 를 채워 위의 리스트를 시리즈로 바꿔보자.

# %%
pd.Series(XXX)

# %%
registrations = [True, False, False, False, True]

# %% [markdown]
# * XXX 를 채워 리스트를 시리즈로 바꿔보자.

# %%
pd.Series(XXX)

# %% [markdown]
# * 위에서 dtype 이 int 64 이고, dtype 이 bool 이라는 것을 확인하자.
# * dtype = int64 는 하나의 숫자를 표현하는데에 64bit 가 사용되는 형태라는 것임.

# %% [markdown]
# ## 2. Create a Series Object from a Dictionary

# %% [markdown]
# ### 2-1. dictionary 에서 시리즈로 변형

# %%
sushi = {
    "Salmon": "Orange",
    "Tuna": "Red",
    "Eel": "Brown"
}

# %% [markdown]
# * 인덱스가 딕셔너리의 key 값으로 바뀌었다는 것을 확인해야함.

# %%
pd.Series(XXX) # 시리즈로

# %% [markdown]
# ## 3. Intro to Series Methods
# - The syntax to invoke a method on any object is `object.method()`.
# - The `sum` method adds together the **Series'** values.
# - The `product` method multiplies the **Series'** values.
# - The `mean` method finds the average of the **Series'** values.
# - The `std` method finds the standard deviation of the **Series'** values.

# %% [markdown]
# ### (1) 다음 가격 리스트를 시리즈로 바꾼 후 시리즈에서 사용되는 methods 를 적용해보자.

# %%
prices = pd.XXX([2.99, 4.45, 1.36]) # 시리즈로 숫자 리스트 변형
prices

# %%
prices.sum()

# %%
prices.product() # 어떻게 나온 값일까?

# %%
prices.mean()

# %%
prices.std()

# %% [markdown]
# ---

# %% [markdown]
# ### (2) 다음 문제에서 요구하는 시리즈를 생성해보자. 넘파이 np 의 random 모듈의 randn 을 써서 정규분포에서 무작위로 4개의 수를 뽑아 시리즈를 만들어보자. 이 때, 인덱스는 'a', 'b', 'c', 'd' 로 설정한다.

# %%
ser = pd.Series(XXX, index=['a', 'b', 'c', 'd'])
ser

# %%
print(ser)

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Intro to Attributes
# - An **attribute** is a piece of data that lives on an object.
# - An **attribute** is a fact, a detail, a characteristic of the object.
# - Access an attribute with `object.attribute` syntax.
# - The `size` attribute returns a count of the number of values in the **Series**.
# - The `is_unique` attribute returns True if the **Series** has no duplicate values.
# - The `values` and `index` attributes return the underlying objects that holds the **Series'** values and index labels.

# %% [markdown]
# * 속성(attribute)은 객체(object) 내에 존재하는 데이터이다.즉, 속성은 특정 객체가 가지고 있는 정보(데이터)를 의미. (파이썬은 객체지향 언어니까?!)
# * 속성은 객체의 사실, 세부 정보, 특성을 나타낸다.
#   * 예를 들어, Series 객체가 있다면, size, values, index 같은 속성들은 Series가 가지고 있는 정보(특성)임.
# * 객체의 속성에 접근할 때는 object.attribute 구문을 사용한다.
# ```
# import pandas as pd
# ser = pd.Series([1, 2, 3])
# print(ser.size)  # 속성에 접근: 3
# ```
#   * 여기서 ser.size처럼 객체 이름 + 점(.) + 속성 이름을 사용하여 속성 값을 가져올 수 있음.

# %%
adjectives = pd.XXX(["Smart", "Handsome", "Charming", "Brilliant", "Humble", "Smart"])
adjectives

# %%
adjectives.size

# %% [markdown]
# * is_unique는 데이터가 고유한지(중복 없는지) 확인할 때 유용함.

# %%
adjectives.is_unique

# %% [markdown]
# * values와 index 속성은 Series의 값과 인덱스를 저장하는 객체를 반환한다.

# %%
adjectives.values # 무엇을 반환하는지 설명하라.

# %%
adjectives.index # 무엇을 반환하는지 설명하라.

# %%
type(adjectives.values) # 무엇을 반환하는지 설명하라.

# %%
type(adjectives.index) # 무엇을 반환하는지 설명하라.

# %% [markdown]
# ---

# %% [markdown]
# ### (1) 다음 딕셔너리를 시리즈로 변환하고, 해당 시리즈의 값과 인덱스를 추출하여 각각 val, ind 변수에 할당하라. 이 때, ind 와 val 의 데이터 타입도 확인하라.

# %%
da = {'seoul' : 2000, 'busan' : 2500, 'daejeon' : 3000}

# %%
# here
ser_da = pd.Series(XX)
...

# %% [markdown]
# ### ** pandas.Index vs. numpy.ndarray 비교 **

# %% [markdown]
# #### (1-1)  Index는 불변(Immutable)

# %% [markdown]
# * pandas.Index는 변경 불가능(immutable) → 직접 값 변경 불가
# * 반면 numpy.ndarray는 변경 가능(mutable)

# %%
ser_da.index[0] = 'x'  # 오류 발생 (Index는 불변)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 새로운 Index 생성을 통한 전반적인 변화 가능

# %%
ser_da.index = ['x', 'y', 'z']  # 가능

# %% [markdown]
# #### (1-2) Index는 집합(Set) 연산 지원

# %%
idx1 = pd.Index(['a', 'b', 'c'])
idx2 = pd.Index(['b', 'c', 'd'])

# %%
print(idx1.XXX(idx2))  # 교집합
print(idx1.XXX(idx2))         # 합집합
print(idx1.XXX(idx2))    # 차집합

# %% [markdown]
# #### (1-3) numpy.ndarray는 수학 연산에 적합

# %%
arr = ser_da.XXX # numpy 배열의 값들
print(arr + 10)   # 벡터 연산 가능

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ### (2) 인덱스 포함해서 시리즈 만들기: 여러 사례

# %%
da = {'a' : 0., 'b' : 1., 'c' : 2.}

# %% [markdown]
# ### (2-1) 없던 인덱스 포함 경우

# %% [markdown]
# * 원래 dict 에서 인덱스로 존재하지 않던 값 'd' 가 포함되어 NaN 값으로 할당됨.

# %%
moreindex = pd.Series(da, index = ['b', 'c', 'd', 'a'])
moreindex

# %% [markdown]
# ### (2-2) 하나의 스칼라값으로 만들라고 하면?

# %%
pd.Series(7., index=['a', 'b', 'c']) # 어떻게 처리하는가?

# %% [markdown]
# ### (2-3) 인덱스로 부르기

# %% [markdown]
# * 현재 pandas.Series에서 ser[0]이 "위치(positional)" 인덱싱과 "라벨(label)" 인덱싱 둘 다 가능하기 때문에, 헷갈릴 수 있는 문제가 있음.

# %%
ser = pd.Series(np.random.randn(4), index=['a', 'b', 'c', 'd'])
print(ser[0])
print(ser.iloc[0]) # 권장되는 방법: 순서 인덱스를 쓰려고 한다면
print(ser.loc['a']) # 권장되는 방법: 원래 인덱스에 적힌 라벨 사용

# %% [markdown]
# ### (2-4) 시리즈에 슬라이싱하기

# %%
ser3 = ser[:3]
print(ser3)
print(ser)

# %% [markdown]
# ### (2-5) 시리즈를 바로 함수에 적용

# %%
exp_ser = np.exp(ser)
print(exp_ser)

# %% [markdown]
# ### (2-6) 시리즈에 이름 달기

# %%
ser = pd.Series(XXX, name='seoul') # 정규분포에서 난수 5개 뽑아서 이름 seoul 인 시리즈 만들기
ser

# %% [markdown]
# ## 5. Parameters and Arguments
# - A **parameter** is the name for an expected input to a function/method/class instantiation.
# - An **argument** is the concrete value we provide for a parameter during invocation.
# - We can pass arguments either sequentially (based on parameter order) or with explicit parameter names written out.
# - The first two parameters for the **Series** constructor are `data` and `index`, which represent the values and the index labels.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
fruits = ["Apple", "Orange", "Plum", "Grape", "Blueberry", "Watermelon"]
weekdays = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Monday"]

# %% [markdown]
# ### (1) 다음 시리즈들이 만들어지는 형태의 차이를 정리하라.

# %%
pd.Series(fruits)

# %%
pd.Series(weekdays)

# %%
pd.Series(fruits, weekdays)

# %%
pd.Series(weekdays, fruits)

# %%
pd.Series(data=fruits, index=weekdays)

# %%
pd.Series(index=weekdays, data=fruits)

# %% [markdown]
# * 지금 뭘 배우고 있는거야? 정리해보자.

# %%
# here

# %%
pd.Series(fruits, index=weekdays)

# %%
pd.Series(fruits)

# %%
pd.Series() # 비어있는 시리즈 만들기
