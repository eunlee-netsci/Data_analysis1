# %% [markdown]
# # Working with Text Data

# %% [markdown]
# # 텍스트 데이터 다루기

# %%
import pandas as pd

# %% [markdown]
# ## This Module's Dataset
# - This module's dataset (`chicago.csv`) is a collection of public sector employees in the city of Chicago.
# - Each row inclues the employee's name, position, department, and salary.

# %% [markdown]
# ## 이번 모듈의 데이터셋
# - 이번 모듈의 데이터는 Netflix TV 쇼 및 영화에 대한 제목과 설명으로 구성되어 있습니다.

# %%
chicago = pd.read_csv("chicago.csv").dropna(how="all")
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %% [markdown]
# * info() 를 확인해보자.

# %%
# 여기에
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32062 entries, 0 to 32061
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  object
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: object(4)
# memory usage: 1.2+ MB

# %% [markdown]
# * 열 별로 고유값이 몇개씩 있는지 확인해보자.

# %%
# 여기에
chicago.nunique()
# Out:
# Name                      31776
# Position Title             1093
# Department                   35
# Employee Annual Salary     1156
# dtype: int64

# %% [markdown]
# * Department 의 타입을 카테고리로 바꿔보자.

# %%
# 여기에
chicago["Department"] = chicago["Department"].astype("category")

# %% [markdown]
# * info() 를 써서 타입이 잘 바뀌었는지 확인해보자.

# %%
# 여기에
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32062 entries, 0 to 32061
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  category
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: category(1), object(3)
# memory usage: 1.0+ MB

# %% [markdown]
# * 다시 깨끗하게 불러오자. dropna 를 써서 모든 열의 값이 NaN 인 경우에 대해서 데이터를 정리한 후, Department 의 타입을 카테고리로 바꿔보자.

# %%
# 여기에
chicago = pd.read_csv("chicago.csv").dropna(how="all")
chicago["Department"] = chicago["Department"].astype("category")
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %% [markdown]
# # Dataframe 의 접근자

# %% [markdown]
# ## Common String Methods
# - A **Series** has a special `str` attribute that exposes an object with string methods.
# - Access the `str` attribute, then invoke the string method on the nested object.
# - Most method names will match their Python method equivalents (`upper`, `lower`, `title`, etc).

# %% [markdown]
# ## 문자열의 일반적인 메서드
# - **Series**는 문자열 데이터를 다룰 수 있는 `.str` 접근자를 제공합니다.
# - 예: `lower()`, `len()`, `contains()` 등

# %%
chicago = pd.read_csv("chicago.csv").dropna(how="all")
chicago["Department"] = chicago["Department"].astype("category")
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 문자열 접근자를 활용하여 Position Title 을 소문자, 대문자로 바꿔보고, 공백을 버리는 함수를 한번에 적용해보자.

# %%
chicago["Position Title"]
# Out:
# 0                      WATER RATE TAKER
# 1                        POLICE OFFICER
# 2                        POLICE OFFICER
# 3              CHIEF CONTRACT EXPEDITER
# 4                     CIVIL ENGINEER IV
#                       ...
# 32057    FRM OF MACHINISTS - AUTOMOTIVE
# 32058                    POLICE OFFICER
# 32059                    POLICE OFFICER
# 32060                    POLICE OFFICER
# 32061           CHIEF DATA BASE ANALYST
# Name: Position Title, Length: 32062, dtype: object

# %%
# 여기에
chicago["Position Title"].str.lower()
# Out:
# 0                      water rate taker
# 1                        police officer
# 2                        police officer
# 3              chief contract expediter
# 4                     civil engineer iv
#                       ...
# 32057    frm of machinists - automotive
# 32058                    police officer
# 32059                    police officer
# 32060                    police officer
# 32061           chief data base analyst
# Name: Position Title, Length: 32062, dtype: object

# %%
chicago["Position Title"].str.strip()
# Out:
# 0                      WATER RATE TAKER
# 1                        POLICE OFFICER
# 2                        POLICE OFFICER
# 3              CHIEF CONTRACT EXPEDITER
# 4                     CIVIL ENGINEER IV
#                       ...
# 32057    FRM OF MACHINISTS - AUTOMOTIVE
# 32058                    POLICE OFFICER
# 32059                    POLICE OFFICER
# 32060                    POLICE OFFICER
# 32061           CHIEF DATA BASE ANALYST
# Name: Position Title, Length: 32062, dtype: object

# %% [markdown]
# * 왼쪽 오른쪽 공백을 각각 떼어내보자.

# %%
# 여기에
chicago["Position Title"].str.lstrip()
# Out:
# 0                      WATER RATE TAKER
# 1                        POLICE OFFICER
# 2                        POLICE OFFICER
# 3              CHIEF CONTRACT EXPEDITER
# 4                     CIVIL ENGINEER IV
#                       ...
# 32057    FRM OF MACHINISTS - AUTOMOTIVE
# 32058                    POLICE OFFICER
# 32059                    POLICE OFFICER
# 32060                    POLICE OFFICER
# 32061           CHIEF DATA BASE ANALYST
# Name: Position Title, Length: 32062, dtype: object

# %%
chicago["Position Title"].str.rstrip()
# Out:
# 0                      WATER RATE TAKER
# 1                        POLICE OFFICER
# 2                        POLICE OFFICER
# 3              CHIEF CONTRACT EXPEDITER
# 4                     CIVIL ENGINEER IV
#                       ...
# 32057    FRM OF MACHINISTS - AUTOMOTIVE
# 32058                    POLICE OFFICER
# 32059                    POLICE OFFICER
# 32060                    POLICE OFFICER
# 32061           CHIEF DATA BASE ANALYST
# Name: Position Title, Length: 32062, dtype: object

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * title() 함수를 써서 단어 맨 앞 글자만 대문자로 바꿔보자.

# %%
# 여기에
chicago["Position Title"].str.title()
# Out:
# 0                      Water Rate Taker
# 1                        Police Officer
# 2                        Police Officer
# 3              Chief Contract Expediter
# 4                     Civil Engineer Iv
#                       ...
# 32057    Frm Of Machinists - Automotive
# 32058                    Police Officer
# 32059                    Police Officer
# 32060                    Police Officer
# 32061           Chief Data Base Analyst
# Name: Position Title, Length: 32062, dtype: object

# %% [markdown]
# * 각 단어 앞글자를 대문자로 만든다음, 해당 시리즈의 길이를 측정하도록 해보자.

# %%
# 여기에
chicago["Position Title"].str.title().str.len()
# Out:
# 0        16
# 1        14
# 2        14
# 3        24
# 4        17
#          ..
# 32057    30
# 32058    14
# 32059    14
# 32060    14
# 32061    23
# Name: Position Title, Length: 32062, dtype: int64

# %% [markdown]
# * Department 열의 MGMNT 를 MANAGEMENT 로 다 바꾸고, 단어의 맨 앞 글자를 대문자로 바꿔보자.

# %%
# 여기에
chicago["Position Title"].str.replace("MGMNT", "MANAGEMENT").str.title()
# Out:
# 0                      Water Rate Taker
# 1                        Police Officer
# 2                        Police Officer
# 3              Chief Contract Expediter
# 4                     Civil Engineer Iv
#                       ...
# 32057    Frm Of Machinists - Automotive
# 32058                    Police Officer
# 32059                    Police Officer
# 32060                    Police Officer
# 32061           Chief Data Base Analyst
# Name: Position Title, Length: 32062, dtype: object

# %% [markdown]
# ## Filtering with String Methods
# - The `str.contains` method checks whether a substring exists anywhere in the string.
# - The `str.startswith` method checks whether a substring exists at the start of the string.
# - The `str.endswith` method checks whether a substring exists at the end of the string.

# %% [markdown]
# ## 문자열 메서드를 이용한 필터링
# - `str.contains()`는 특정 문자열이 포함되어 있는지를 검사하여 필터링할 수 있습니다.
# - 대소문자 구분 없이 검색하려면 `case=False`를 사용합니다.
# - str.contains 메서드는 문자열 안에 특정 부분 문자열이 어디에든 존재하는지 확인합니다.
# - str.startswith 메서드는 문자열이 특정 부분 문자열로 시작하는지 확인합니다.
# - str.endswith 메서드는 문자열이 특정 부분 문자열로 끝나는지 확인합니다.

# %%
# chicago.csv 를 모두 NA 부분을 버린 상태로 불러오고, Department 타입을 카테고리로 변경하자.
chicago = pd.read_csv("chicago.csv").dropna(how="all")
chicago["Department"] = chicago["Department"].astype("category")
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %% [markdown]
# * 이 때, 물 (water) 관련 직무를 보는 사람들을 찾기 위해 Position Title 을 모두 소문자로 바꾸고, 그 직책에 water 가 들어있는 직무를 추출하자.

# %%
# 여기에
water_workers = chicago["Position Title"].str.lower().str.contains("water") # filter
chicago[water_workers]
# Out:
#                        Name                                 Position Title  \
# 0           AARON,  ELVIA J                               WATER RATE TAKER
# 554      ALUISE,  VINCENT G             FOREMAN OF WATER PIPE CONSTRUCTION
# 671         ANDER,  PERRY A                               WATER CHEMIST II
# 685     ANDERSON,  ANDREW J  DISTRICT SUPERINTENDENT OF WATER DISTRIBUTION
# 702       ANDERSON,  DONALD             FOREMAN OF WATER PIPE CONSTRUCTION
# ...                     ...                                            ...
# 29669        VERMA,  ANUPAM           MANAGING ENGINEER - WATER MANAGEMENT
# 30239   WASHINGTON,  JOSEPH                              WATER CHEMIST III
# 30544       WEST,  THOMAS R                   GEN SUPT OF WATER MANAGEMENT
# 30991    WILLIAMS,  MATTHEW             FOREMAN OF WATER PIPE CONSTRUCTION
# 31405  WOODRIDGE,  ROBERT L             FOREMAN OF WATER PIPE CONSTRUCTION
#
#         Department Employee Annual Salary
# ...

# %% [markdown]
# * 이번에는 도시 관련 (civil) 직책을 찾기 위해, civil 로 시작하는 Position Title 을 갖는 사람들만 추출해보자.

# %%
# 여기에

# %% [markdown]
# * 이번에는 Position Title 에서 iv 가 포함된 포지션만 추출하자.

# %%
# 여기에
ends_with_iv = chicago["Position Title"].str.lower().str.endswith("iv")
chicago[ends_with_iv]
# Out:
#                         Name          Position Title      Department  \
# 4        ABAD JR,  VICENTE M       CIVIL ENGINEER IV     WATER MGMNT
# 34        ABRAHAM,  GIRLEY T       CIVIL ENGINEER IV     WATER MGMNT
# 145        ADAMS,  SHERYLL A            LIBRARIAN IV  PUBLIC LIBRARY
# 147         ADAMS,  TANERA C       CIVIL ENGINEER IV      TRANSPORTN
# 166        ADENI,  MOHAMED K           ACCOUNTANT IV         FINANCE
# ...                      ...                     ...             ...
# 31777  ZAFIRIS,  CHRISTOPHER            ARCHITECT IV    DISABILITIES
# 31797        ZAKE,  JOSHUA S       CIVIL ENGINEER IV      TRANSPORTN
# 31870      ZAVALA,  FERNANDO           ACCOUNTANT IV         FINANCE
# 31884       ZAWADSKI,  JAMES                CLERK IV             LAW
# 32008        ZOTTA,  SANDINO  MECHANICAL ENGINEER IV     WATER MGMNT
#
#       Employee Annual Salary
# 4                 $106836.00
# 34                $106836.00
# 145                $97812.00
# ...

# %% [markdown]
# ## String Methods on Index and Columns
# - Use the `index` and `columns` attributes to access the **DataFrame** index/column labels.
# - These objects support string methods via their own `str` attribute.

# %% [markdown]
# ## 인덱스 및 열에서의 문자열 메서드 사용
# - `str` 메서드는 인덱스와 열 이름에도 사용할 수 있습니다.
# - 예: 열 이름을 소문자로 변환하거나 특정 단어가 포함된 열 찾기 등

# %%
chicago = pd.read_csv("chicago.csv", index_col="Name").dropna(how="all").sort_index()
chicago["Department"] = chicago["Department"].astype("category")
chicago.head()
# Out:
#                                Position Title        Department  \
# Name
# AARON,  ELVIA J              WATER RATE TAKER       WATER MGMNT
# AARON,  JEFFERY M              POLICE OFFICER            POLICE
# AARON,  KARINA                 POLICE OFFICER            POLICE
# AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#                     Employee Annual Salary
# Name
# AARON,  ELVIA J                  $90744.00
# AARON,  JEFFERY M                $84450.00
# AARON,  KARINA                   $84450.00
# AARON,  KIMBERLEI R              $89880.00
# ABAD JR,  VICENTE M             $106836.00

# %% [markdown]
# * index 의 공백을 다 떼고 (양 옆), 단어 앞글자를 대문자로 바꿔보자.

# %%
# 여기에
chicago.index = chicago.index.str.strip().str.title()

# %% [markdown]
# * 열이름을 모두 대문자로 변형하자.

# %%
# 여기에
chicago.columns = chicago.columns.str.upper()

# %%
chicago.head() # 잘 변형되었는지 확인
# Out:
#                                POSITION TITLE        DEPARTMENT  \
# Name
# Aaron,  Elvia J              WATER RATE TAKER       WATER MGMNT
# Aaron,  Jeffery M              POLICE OFFICER            POLICE
# Aaron,  Karina                 POLICE OFFICER            POLICE
# Aaron,  Kimberlei R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# Abad Jr,  Vicente M         CIVIL ENGINEER IV       WATER MGMNT
#
#                     EMPLOYEE ANNUAL SALARY
# Name
# Aaron,  Elvia J                  $90744.00
# Aaron,  Jeffery M                $84450.00
# Aaron,  Karina                   $84450.00
# Aaron,  Kimberlei R              $89880.00
# Abad Jr,  Vicente M             $106836.00

# %% [markdown]
# ## The split Method
# - The `str.split` method splits a string by the occurrence of a delimiter. Pandas returns a **Series** of lists.
# - Use the `str.get` method to access a nested list element by its index position.

# %% [markdown]
# ## split 메서드
# - str.split 메서드는 문자열을 특정 구분자가 나타나는 위치를 기준으로 나누어 줍니다.
# - Pandas는 이를 리스트들의 Series로 반환합니다.
# 중첩된 리스트의 원소를 인덱스로 접근하려면 str.get 메서드를 사용하세요.

# %%
chicago = pd.read_csv("chicago.csv").dropna(how="all")
chicago["Department"] = chicago["Department"].astype("category")
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %% [markdown]
# * Position Title 에 있는 포지션들을 공백기준으로 한번에 나누어서 각가 리스트로 반환받아보자.

# %%
# 여기에
chicago["Position Title"].str.split(" ")
# Out:
# 0                        [WATER, RATE, TAKER]
# 1                           [POLICE, OFFICER]
# 2                           [POLICE, OFFICER]
# 3                [CHIEF, CONTRACT, EXPEDITER]
# 4                       [CIVIL, ENGINEER, IV]
#                          ...
# 32057    [FRM, OF, MACHINISTS, -, AUTOMOTIVE]
# 32058                       [POLICE, OFFICER]
# 32059                       [POLICE, OFFICER]
# 32060                       [POLICE, OFFICER]
# 32061            [CHIEF, DATA, BASE, ANALYST]
# Name: Position Title, Length: 32062, dtype: object

# %% [markdown]
# * 여기서 앞 단어만 get() 을 사용하여 추출하고, 앞 단어들의 빈도를 측정하라.

# %%
# 여기에
chicago["Position Title"].str.split(" ").str.get(0).value_counts()
# Out:
# Position Title
# POLICE             10856
# FIREFIGHTER-EMT     1509
# SERGEANT            1186
# POOL                 918
# FIREFIGHTER          810
#                    ...
# PORTFOLIO              1
# SUPERVISOR             1
# SUPT                   1
# STRUCTURAL             1
# CORPORATION            1
# Name: count, Length: 320, dtype: int64

# %% [markdown]
# ## More Practice with Splits

# %%
chicago = pd.read_csv("chicago.csv").dropna(how="all")
chicago["Department"] = chicago["Department"].astype("category")
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %% [markdown]
# * Name 을 ", " 기준으로 나누고, 그 중 이름 (1번째 인덱스) 를 갖고 와서, 양쪽 공백을 제거하고, 이를 공백기준으로 나눠서, 중간 이름을 제외한 이름이 각각 몇번씩 등장했는지 카운트해보자.

# %%
# 여기에

# %% [markdown]
# ## The expand and n Parameters of the split Method
# - The `expand` parameter returns a **DataFrame** instead of a **Series** of lists.
# - The `n` parameter limits the number of splits.

# %%
chicago = pd.read_csv("chicago.csv").dropna(how="all")
chicago["Department"] = chicago["Department"].astype("category")
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %% [markdown]
# ##  expand 사용

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
chicago[["Last Name", "First Name"]] = chicago["Name"].str.split(",", expand=True)

# %%
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary Last Name     First Name
# 0              $90744.00     AARON        ELVIA J
# 1              $84450.00     AARON      JEFFERY M
# 2              $84450.00     AARON         KARINA
# 3              $89880.00     AARON    KIMBERLEI R
# 4             $106836.00   ABAD JR      VICENTE M

# %% [markdown]
# * Position Title 을 공백 기준으로 나누고, Primary Title, Secondary Title 열을 만들자.

# %%
# 여기에
chicago[["First title", "Second title"]] = chicago["Position Title"].str.split(" ", expand = True, n = 1)

# %%
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary Last Name     First Name First title  \
# 0              $90744.00     AARON        ELVIA J       WATER
# 1              $84450.00     AARON      JEFFERY M      POLICE
# 2              $84450.00     AARON         KARINA      POLICE
# 3              $89880.00     AARON    KIMBERLEI R       CHIEF
# 4             $106836.00   ABAD JR      VICENTE M       CIVIL
#
#          Second title
# 0          RATE TAKER
# 1             OFFICER
# 2             OFFICER
# 3  CONTRACT EXPEDITER
# 4         ENGINEER IV
